# %%
# Import data

# %%
import pandas as pd

# %%
pd.read_csv("data/20220915_HackZurich_Sensirion_v1.csv")
# Out:
#                 Unnamed: 0  temperature_ventilation_system_fresh_air_in  \
# 0      2021-05-02 00:00:00                                          NaN
# 1      2021-05-02 00:10:00                                          NaN
# 2      2021-05-02 00:20:00                                          NaN
# 3      2021-05-02 00:30:00                                          NaN
# 4      2021-05-02 00:40:00                                          NaN
# ...                    ...                                          ...
# 69980  2022-08-30 23:20:00                                         17.2
# 69981  2022-08-30 23:30:00                                         17.1
# 69982  2022-08-30 23:40:00                                         17.3
# 69983  2022-08-30 23:50:00                                         17.5
# 69984  2022-08-31 00:00:00                                         17.4
#
#        temperature_ventilation_system_fresh_air_intermediate  \
# ...
